# %% [markdown]
# THIS IS A PRACTICE EXAMPLE FROM ANDREAS C.MULLER AND SARAH GUIDO'S BOOK.
#
# HERE I'M REPLICATING THE RANDOM FORESTS MODEL ON BREAST CANCER DATA

# %%
#Importing necesary datasets and modules

from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import graphviz
import matplotlib.pyplot as plt
import numpy as np
import mglearn

# %%
#Splitting the data
cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, random_state=0)

#Fitting the model on the date
forest = RandomForestClassifier(n_estimators=100, random_state=0)
forest.fit(X_train, y_train)

#Testing model accuracy

print("Accuracy on training data is {:.3f}".format(forest.score(X_train, y_train)))
print("Accuracy on test data is {:.3f}".format(forest.score(X_test, y_test)))
# Out:
# Accuracy on training data is 1.000
# Accuracy on test data is 0.972

# %%
#Visualizing feature importance
def plot_feature_importances_cancer(model):
    n_features = cancer.data.shape[1]
    plt.barh(range(n_features), model.feature_importances_, align='center')
    plt.yticks(np.arange(n_features), cancer.feature_names)
    plt.xlabel("Feature importance")
    plt.ylabel("Feature")
    plt.show()
    
plot_feature_importances_cancer(forest)
